# %%
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from PIL import Image
import pytesseract as pt
import numpy as np
import plotly.express as px

# %%
# Load model
model = tf.keras.models.load_model('./models/object_detection.keras')
print('Model loaded Sucessfully')
# Out:
# WARNING:tensorflow:From c:\Users\t.waluga\Documents\Codecool\Projects\AI-ML-Summary-Project\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Model loaded Sucessfully

# %%
path = 'data/TEST/TEST.jpeg'
image = load_img(path) # PIL object
image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)
image1 = load_img(path,target_size=(224,224))
image_arr_224 = img_to_array(image1)/255.0  # Convert into array and get the normalized output

# Size of the orginal image
h,w,d = image.shape
print('Height of the image =',h)
print('Width of the image =',w)
# Out:
# Height of the image = 729
# Width of the image = 901

# %%
fig = px.imshow(image)
fig.update_layout(width=700, height=500,  margin=dict(l=10, r=10, b=10, t=10), xaxis_title='Figure 13 - TEST Image')

# %%
path = 'data/TEST/TEST.jpeg'
image = load_img(path) # PIL object
image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)
image1 = load_img(path,target_size=(224,224))
image_arr_224 = img_to_array(image1)/255.0  # Convert into array and get the normalized output

# Size of the orginal image
h,w,d = image.shape
print('Height of the image =',h)
print('Width of the image =',w)

# %%
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
test_arr = image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
# Make predictions
coords = model.predict(test_arr)
coords
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# array([[0.31702945, 0.66018975, 0.7010728 , 0.737712  ]], dtype=float32)

# %%
# Denormalize the values
denorm = np.array([w,w,h,h])
coords = coords * denorm
coords
# Out:
# array([[285.64353117, 594.83096278, 511.08208001, 537.79206669]])

# %%
coords = coords.astype(np.int32)
coords
# Out:
# array([[285, 594, 511, 537]], dtype=int32)

# %%
# Draw bounding on top the image
xmin, xmax, ymin, ymax = coords[0]
pt1 = (xmin, ymin)
pt2 = (xmax, ymax)
print(pt1, pt2)
# Out:
# (np.int32(285), np.int32(511)) (np.int32(594), np.int32(537))

# %%
cv2.rectangle(image,pt1,pt2,(0,255,0),3)
fig = px.imshow(image)
fig.update_layout(width=700, height=500, margin=dict(l=10, r=10, b=10, t=10))

# %%
# Create pipeline
path = 'data/TEST/TEST.jpeg'
def object_detection(path):
    
    # Read image
    image = load_img(path) # PIL object
    image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)
    image1 = load_img(path,target_size=(224,224))
    
    # Data preprocessing
    image_arr_224 = img_to_array(image1)/255.0 # Convert to array & normalized
    h,w,d = image.shape
    test_arr = image_arr_224.reshape(1,224,224,3)
    
    # Make predictions
    coords = model.predict(test_arr)
    
    # Denormalize the values
    denorm = np.array([w,w,h,h])
    coords = coords * denorm
    coords = coords.astype(np.int32)
    
    # Draw bounding on top the image
    xmin, xmax,ymin,ymax = coords[0]
    pt1 = (xmin, ymin)
    pt2 = (xmax, ymax)
    print(pt1, pt2)
    cv2.rectangle(image,pt1,pt2,(0,255,0),3)
    return image, coords

image, cods = object_detection(path)

fig = px.imshow(image)
fig.update_layout(width=700, height=500, margin=dict(l=10, r=10, b=10, t=10),xaxis_title='Figure 14')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# (np.int32(285), np.int32(511)) (np.int32(594), np.int32(537))

# %%
img = np.array(load_img(path))
xmin, xmax, ymin, ymax = cods[0]
roi = img[ymin:ymax, xmin:xmax]
roi = img[485:533, 328:580]
fig = px.imshow(roi)
fig.update_layout(width=350, height=250, margin=dict(l=10, r=10, b=10, t=10),xaxis_title='Figure 15 Cropped image')

# %%
# extract text from image
pt.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
text = pt.image_to_string(roi)
print(text)
# Out:
# KL Si K 4999
